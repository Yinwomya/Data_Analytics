# %%
from matplotlib.pyplot import pie, show

# %%
from numpy import array

# %%
data_set=array([25, 20, 50, 15])
labls=['Apples', 'Bananas', 'Cherries', 'Mangoes']
titl=['Pie Chart of Fruits']

# %%
pie(data_set, labels= labls)
show()
